# %%
import os
import pandas as pd
import re
import numpy as np
from datetime import datetime
from openpyxl import load_workbook
import warnings


warnings.filterwarnings("ignore", category=UserWarning, module='openpyxl')


# input

your_ing_id = 'XO21BM'
date = datetime.strptime('2024', "%Y")

directory_path0 = os.getcwd()
directory_path = path = f"/Users/{your_ing_id}/Library/CloudStorage/OneDrive-SharedLibraries-ING/Product Evaluation and Risk Assessment Library (PEARL) - PEARL_Repository"
directory_path2 = path = f"/Users/{your_ing_id}/Library/CloudStorage/OneDrive-SharedLibraries-ING/Product Evaluation and Risk Assessment Library (PEARL) - MI Dashboard"

# %%
# folder and ID mapping
overview = pd.read_csv('PEARL List (1).csv', sep=',', low_memory=False)
overview['Folder_URL_txt'] = overview['Folder_URL_txt'].str.replace('#$@', ' ')
overview['Folder'] = overview['Folder_URL_txt'].str.replace(r'https://ing.sharepoint.com/sites/PEARL_cs/Shared Documents/Pearl_Repository/', '')
overview['Folder'] = overview['Folder'].str.replace(r'https://ing.sharepoint.com/sites/PEARL_cs/Shared Documents/PEARL_Repository/', '')
cols_overview = ['Folder', 'ID']
overview = overview[cols_overview]
overview['ID'] = overview['ID'].astype(str)

# %%
# reading MI dashboard
file_name = 'MI Dashboard.xlsm'
file_path = os.path.join(directory_path2, file_name)

# %%
# Changes
# reading MI dashboard
file_name = 'MI Dashboard.xlsm'
file_path = os.path.join(directory_path2, file_name)

# Changes
mi_dash_changes = pd.read_excel(file_path, sheet_name="Management Info Changes", engine="openpyxl", skiprows=2)
mi_dash_changes.rename(columns={'PEARL ID': 'ID'}, inplace=True)

mi_dash_changes.loc[mi_dash_changes['End Date'] == '(blank)', 'End Date'] = np.nan
mi_dash_changes.loc[mi_dash_changes['Start Date'] == '(blank)', 'Start Date'] = np.nan
mi_dash_changes['End Date'] = pd.to_datetime(mi_dash_changes['End Date'])
mi_dash_changes['Start Date'] = pd.to_datetime(mi_dash_changes['Start Date'])


mi_dash_changes['Type'] = 'Change'

# %%
# Reviews
mi_dash_review = pd.read_excel(file_path, sheet_name="Management Info Reviews", engine="openpyxl", skiprows=2)
mi_dash_review.rename(columns={'RJT Review PEARL ID': 'ID', 
                               'RJT Review Start Date': 'Start Date', 
                               'RJT Review Approval Date': 'End Date', 
                               'RJT Review Status': 'Status'}, inplace=True)

# filtering only the relevant ones for our current analysis on the complete ones
mi_dash_review.loc[mi_dash_review['End Date'] == '(blank)', 'End Date'] = np.nan
mi_dash_review.loc[mi_dash_review['Start Date'] == '(blank)', 'Start Date'] = np.nan
mi_dash_review['End Date'] = pd.to_datetime(mi_dash_review['End Date'])
mi_dash_review['Start Date'] = pd.to_datetime(mi_dash_review['Start Date'])

mi_dash_review['Type'] = 'Review'

# %%
#mi_risk_module = pd.read_excel(file_path, sheet_name="Risk Modules", engine="openpyxl", skiprows=2)

# creating overview so we know in which risk assesments we are interested in
final_overview = pd.concat([mi_dash_changes, mi_dash_review])


cond = ~(final_overview['End Date'] < date) & ~(final_overview['ID'].isna())
final_overview = final_overview[cond]
cols = ['ID', 'Start Date', 'End Date', 'Process Category', 'Tribe', 'Status', 'Type', 'Duration']
final_overview = final_overview[cols]
final_overview = final_overview.merge(overview, how = 'left', on = 'ID')


final_overview['End Year'] = final_overview['End Date'].dt.year

cond = final_overview['Process Category'].isna()
final_overview.loc[cond, 'Process Category'] = 'empty'

final_overview_grouped = final_overview.groupby([
    'Process Category', 
    'End Year', 
    'Type']).agg({'ID': 'count'}).reset_index()

final_overview.to_csv('final_overview.csv', sep=';', index = False)

final_overview = pd.read_csv('final_overview.csv', sep=';')

# prep for the loop
# result1 = pd.DataFrame()
# result2 = pd.DataFrame()
# result3 = pd.DataFrame()
# result4 = pd.DataFrame()

# %%
def find_matching_strings(strings):
    matching_strings = []
    for string in strings:
        if string.lower().startswith('risk') and 'journey' in string.lower() and string.lower().endswith('xlsm'):
            matching_strings.append(string)
    
    return matching_strings

folders_to_check = final_overview.loc[:, 'Folder']

# for testing and cheking specific folder ########
item_to_find = r'Hypotheken - WUB/WUB Hypotheek met Beleggingsrekening/2024-04-15 Intermediate Review product'
temp_index = 0
for f in folders_to_check:
    
    if f == item_to_find:
        break
    
    temp_index = temp_index + 1
    
folder = folders_to_check.iloc[temp_index] # for testing
folder = folders_to_check.iloc[859] # for testing

# %%
index = 1199 # counter to see progression of the loop  
folders_to_check = folders_to_check[~folders_to_check.isna()]
n = len(folders_to_check)
folders_to_check = folders_to_check[index:n]
folder = folders_to_check.iloc[1, ]


for folder in folders_to_check:
    folder = folder.replace("/", "\\")
    complete_folder_path = directory_path + '\\' + folder + '\\'
    index = index + 1
    
    print(f'Folder {index} {folder}')
    
    if os.path.isdir(complete_folder_path):
        files = os.listdir(complete_folder_path)
        files = find_matching_strings(files)
    else:
        continue
    
    #f = files[0]
    for f in files: # some folders contain two or more rik journey tool excels
        
        file_path = complete_folder_path + f
        try:
            xls = pd.ExcelFile(file_path, engine="openpyxl")
            sheet_names = xls.sheet_names
            modification_time = os.path.getmtime(file_path)
            modification_time = datetime.fromtimestamp(modification_time).strftime('%Y-%m-%d %H:%M:%S')

            
        except Exception as e:
            print(f'File not opened {file_path}.')
            continue
        
        
        if "Process & Module Selection" in sheet_names:
            try:
                df = pd.read_excel(file_path, sheet_name="Process & Module Selection", engine="openpyxl")
                row_index = df.index[df.iloc[:,1] == 'Risk entity']
                
                if row_index.empty == False:
                    row_index = row_index.tolist()[0]
                    orm_row_index = row_index + 1
                    irm_row_index = row_index + 4
                    orm = str(df.iloc[orm_row_index, 1])
                    orm_value = str(df.iloc[orm_row_index, 5])
                    
                    irm = str(df.iloc[irm_row_index, 1])
                    irm_value = str(df.iloc[irm_row_index, 5])
                    
                    data = {'File': [f.lower()], 'ORM_check': [orm], 'ORM': [orm_value],
                            'IRM_check': [irm], 'IRM': [irm_value], 'Folder': [folder]}
                    data = pd.DataFrame(data)
                    data['File date'] = modification_time
                    
                    data.to_csv(directory_path3 + str(index) + '_result1.csv', sep=';', index = False)
                    #result1 = pd.concat([data, result1])
                    
            except Exception as e:
                print("Process & Module Selection NOT opened.")

            
        if "General Risk Identification" in sheet_names:
            
            try:
                df = pd.read_excel(file_path, sheet_name="General Risk Identification", engine="openpyxl")
                row_index = df.index[df.iloc[:,6] == 'Must be invited?']
                
                if row_index.empty == False:
                    row_index = row_index.tolist()[0]
                    orm_row_index = row_index + 1
                    irm_row_index = row_index + 4
                    orm = str(df.iloc[orm_row_index, 1])
                    orm_value = str(df.iloc[orm_row_index, 6])
                    orm_value2 = str(df.iloc[orm_row_index, 9])
                        
                    irm = str(df.iloc[irm_row_index, 1])
                    irm_value = str(df.iloc[irm_row_index, 6])
                    irm_value2 = str(df.iloc[irm_row_index, 9])
                        
                    data = {'File': [f.lower()], 'ORM_check': [orm],'ORM_invited': [orm_value], 'ORM_part_of_risk_asses': [orm_value2],
                                'IRM_check': [irm], 'IRM_invited': [irm_value], 'IRM_part_of_risk_asses': [irm_value2], 'Folder': [folder]}
                    data = pd.DataFrame(data)
                    data['File date'] = modification_time
                    
                    data.to_csv(directory_path3 + str(index) + '_result2.csv', sep=';', index = False)
                    #result2 = pd.concat([data, result2])
                    
            except Exception as e:
                print("General Risk Identification NOT opened.")
                
                
            
        if "Risk Summary & Approval" in sheet_names:
            try:
                df = pd.read_excel(file_path, sheet_name="Risk Summary & Approval", engine="openpyxl")
                row_index = df.index[df.iloc[:,1] == 'Step 4 -  Select Risk Entities to inform or to invite for challenge and agreement']
                if row_index.empty == False:
                    
                    row_index = row_index.tolist()[0]
                    orm_row_index = row_index + 3
                    irm_row_index = row_index + 6
                    orm = str(df.iloc[orm_row_index, 1])
                    orm_value = str(df.iloc[orm_row_index, 4])
                        
                    irm = str(df.iloc[irm_row_index, 1])
                    irm_value = str(df.iloc[irm_row_index, 4])
                        
                    data = {'File': [f.lower()], 'ORM_check': [orm],'ORM_invited_or_challange': [orm_value],
                                'IRM_check': [irm], 'IRM_invited_or_challange': [irm_value], 'Folder': [folder]}
                    data = pd.DataFrame(data)
                    data['File date'] = modification_time
                    
                    data.to_csv(directory_path3 + str(index) + '_result3.csv', sep=';', index = False)
                    #result3 = pd.concat([data, result3])
            except Exception as e:
                print("Risk Summary & Approval NOT opened.")
            
            
        if "Risk Journey Log" in sheet_names:
            try:
                df = pd.read_excel(file_path, sheet_name="Risk Journey Log", engine="openpyxl")
                row_index = df.index[df.iloc[:,1] == 'Customer Suitability']
                
                if row_index.empty == False:
                    #print(f'File does not contain Step 4 row {file_path}.') to many do not have it - solve it later
                    row_index = row_index.tolist()[0]
                    data = {'Module Title': df.iloc[row_index:(row_index+14),1].tolist(), 
                            'Applicable': df.iloc[row_index:(row_index+14),3].tolist()}
                    
                    data = pd.DataFrame(data)
                    data['File'] = f.lower()
                    data['Folder'] = folder
                    data['File date'] = modification_time
                    
                    data.to_csv(directory_path3 + str(index) + '_result4.csv', sep=';', index = False)
                    #result4 = pd.concat([data, result4])
            except Exception as e:
                print("Risk Journey Log NOT opened.")
                
            df = pd.read_excel(file_path, sheet_name="Risk journey", engine="openpyxl")
# Out:
# Folder 1200 Cash\Verpakt Storten\2024-11-14 update terms and conditions sealbags
# Folder 1201 Credit Cards\Creditcard\2024-11-14 Change authentication level cards IRIS  Risk assessment MIA ISSUE10060964
# Folder 1202 Beyond Banking\ING Punten\2024-11-14 ING Points for Charity
# Folder 1203 \Communication\2024-11-14 Financial Health Content ing.nl
# Folder 1204 Customer Data\Process change\2024-11-14 Epic 5137634 Develop automated solution for charging KYC fee (KKO)
# Folder 1205 Z_Other\Tribe Business Lending\2024-11-15 Sox Annual Figures via SBR  SSC  FINAN
# Folder 1206 Z_Other\Tribe Digital & Customer Interactions\2024-11-15 Throwback Feature
# Folder 1207 Current accounts\G-rekening\2024-11-15 Modification letter Grekening
# Folder 1208 Credit Cards\Creditcard\2024-11-15 Execution Winddown Revolving Credit cards
# Folder 1209 Beleggingsrekeningen\Vermogensbeheer\2024-11-15 Client feedback tool in the DPM order flow  Phase 2
# Folder 1210 Beleggingsrekeningen\Vermogensbeheer\2024-11-15 DPMEB Historical returns widget for ING.nl
# Folder 1211 Beleggingsrekeningen\Vermogensbeheer\2024-11-15 DPM Strategy positions
# Folder 1212 Beleggingsrekeningen\Vermogensbeheer\2024-11-15 DPM Strategy allocation
# Folder 1213 Beleggingsrekeningen\Vermogensbeheer\2024-11-15 Add question to ING.nl FAQ page  What is a LEI and do I need one
# Folder 1214 Digital Sales\Investments - Verdi\2024-11-18 Extra adcopy investments Google Ads
# Folder 1215 Beyond Banking\ING Punten\2024-11-18 ING Punten for minors
# Folder 1216 Kantoren\ING Huizen\2024-11-19 Vooraankondiging bellen door ATH
# Folder 1217 KYC\Organisational change\2024-11-19 Migration to Hubs PL of DR-cases for FATCA and CRS
# Folder 1218 Z_Other\Tribe Business Lending\2024-11-19 Digitize recovery flows  1st MVP PART A
# Folder 1219 Digital Sales\Current accounts\2024-11-19 Studentenrekening Creditcard USP
# Folder 1220 Branding\Communication\2024-11-19 2024 Trustpilot
# Folder 1221 Digital Sales\Investments - Verdi\2024-11-19 Showing returns in table on EB PDP
# Folder 1222 Document & Content Services\Process change\2024-11-19 eSign for qualified signatures
# Folder 1223 Verzekeren\Z_Other\2024-11-20 Reactivation business insurance policy AZ
# Folder 1224 Verzekeren\Z_Other\2024-11-20 Risk based approach CDD for insurance disitrbution
# Folder 1225 Sparen\Z_Other\2024-11-20 Rond Af  Spaar winactie december 2024
# Folder 1226 Digital Sales\Current accounts\2024-11-20 MGM Entrypoint
# Folder 1227 Beleggingsrekeningen\Eenvoudig Beleggen\2024-11-20 Fund Switch communication
# Folder 1228 Beleggingsrekeningen\Vermogensbeheer\2024-11-21 DPM English as a service  Private Banking
# Folder 1229 Digital Sales\Investments - Verdi\2024-11-21 Showing funds details sooner in the journey
# Folder 1230 Beleggingsrekeningen\Eenvoudig Beleggen\2024-11-21 Portfolio Insigts EB
# Folder 1231 Fraud\Process change\2024-11-21 Smart Scam Warnings
# Folder 1232 Private Banking _ Wealth\Z_Other\2024-11-21 LinkedIn post  nav Artikel Infrastructuur Private Markets
# Folder 1233 Lenen zakelijk\Z_Other\2024-11-22 CheckAHead for Fraud MIA
# Folder 1234 Hypotheken\Z_Other\2024-11-22 Normkader Passend Advies januari 2025
# Folder 1366 Hypotheken\Z_Other\2025-01-22 Display components of variable rates on historic mortgage rate page on ing.nl
# Folder 1367 Beleggingsrekeningen\Eenvoudig Beleggen\2025-01-22 ACE EB  Quarterly return update email  Q42024
# Folder 1368 Current accounts\Z_Other\2025-01-22 BSN delivery within a few months after onboarding
# Folder 1369 Datamanagement\Process change\2025-01-22 Data Consumption app
# Folder 1370 Hypotheken\ILM\2025-01-23 ATLBTL campaigns upgrade je huis 2025
# Folder 1371 Customer Data\Process change\2025-01-23 BSN module for private individuals  5456611
# Folder 1372 Private Banking _ Wealth\Salespitches\2025-01-23 Sheets Terugvorderen bronbelasting Maatwerk Vermogensbeheer
# Folder 1373 Lenen zakelijk\Z_Other\2025-01-23 UTPBB202503
# Folder 1374 Credit Cards\Creditcard\2025-01-23 Expand access rights Extra Card holders V2.0
# Folder 1375 Transaction Services\Other\2025-01-24 Package Strategy (Business Banking)
# Folder 1376 Beleggingsrekeningen\Eenvoudig Beleggen\2025-01-24 Acov for exit survey
# Folder 1377 KYC\Process change\2025-01-27 EPIC PPMEPIC0037846Feature 5445133  Improve the IVR Hithandling process
# Folder 1378 Cash\Munten Opnemen\2025-01-27 Enable IBAN collection by Brinks
# Folder 1379 Customer IT Systems & Processes\Process change\2025-01-27 Plan Ahead  Digital customer onboarding
# Folder 1380 Hypotheken\Adviesteam Wonen\2025-01-27 Normkader Passend Advies 15 feb 2025
# Folder 1381 Lenen zakelijk\Z_Other\2025-01-28 PAIS database  Sustainable loan flagging
# Folder 1382 Transaction Services\Communication\2025-01-28 LinkedIn Salesnavigator for ING Checkout
# Folder 1383 Beleggingsrekeningen\Vermogensadvies\2025-01-28 Private Markets dvp
# Folder 1384 Current accounts\Betaalrekening\2025-01-28 English language discliamer
# Folder 1385 Hypotheken\Morse\2025-01-29 Morse ILM Life Events
# Folder 1386 Hypotheken\ILM\2025-01-30 Proactive communication to eligible customers on LTV opportunity on loan component
# Folder 1387 Lenen zakelijk\Z_Other\2025-01-30 Widget Orientation Tool
# Folder 1388 Collections\Process change\2025-01-30 Monitoring suitablility and use of overdraft
# Folder 1389 Hypotheken - WUB\Z_Other\2025-01-30 Self Service Rente Inregelen
# Folder 1390 Z_Other\Tribe Daily Banking & Digital First\2025-01-30 I am expat advertorial Feb 2024
# Folder 1391 Collections\Process change\2024-12-13 Prefill iE form
# Folder 1392 Beleggingsrekeningen\Vermogensadvies\2025-01-31 New journeys for Vermogensadvies
# Folder 1393 Persoonlijke Lening\Persoonlijke Lening\2025-01-31 New2bank loan application
# Folder 1394 Beleggingsrekeningen\Vermogensbeheer\2025-02-03 PDPM pilot
# Folder 1395 Hypotheken\ILM\2025-02-03 Webpage foundation risk
# Folder 1396 Betalen-Roodstand\ING Rood Staan voor studenten\2025-02-03 Rationalize Loan and Overdraft product2025CLFUNDNLILF
# Folder 1397 Z_Other\Tribe Business Lending\2025-02-03 SBR for VRA 7047268
# Folder 1398 Private Banking _ Wealth\Z_Other\2025-02-03 LinkedIn post  artikel Investment Officer modelportefeuille grootbanken
# Folder 1399 Lenen zakelijk\Leningen Inactief-EUROFLX\2025-02-04 Product Management  Adjustment EKP letter Feature 4916077
# Folder 1400 KYC\Process change\2025-02-04 Data actualisation  AAAI
# Folder 1401 Beleggingsrekeningen\Z_Other\2025-02-04 Move to ModifiedDietz calculation
# Folder 1402 Beleggingsrekeningen\Z_Other\2025-02-04 ModifiedDietz
# Folder 1403 Customer Data\Process change\2025-02-04 DPS0310 target functionality change business current account name
# Folder 1404 Persoonlijke Lening\Persoonlijke Lening\2025-02-05 ESIC Issue PLRS
# Folder 1405 Beleggingsrekeningen\Vermogensbeheer\2025-02-05 Update Investment Officer ING best performance
# Folder 1406 Hypotheken\Z_Other\2025-02-05 Update basisinformatie to include climate risks
# Folder 1407 Beleggingsrekeningen\Vermogensbeheer\2025-02-05 DPM Strategy Allocation and Strategy positions  new entry points
# Folder 1408 Z_Other\Tribe Digital & Customer Interactions\2025-02-05 Customer Communication Footprint Tips
# Folder 1409 Customer IT Systems & Processes\Other\2025-02-06 Adding web and minors to GenAI chatbot
# Folder 1410 Digital Sales\Investments - Verdi\2025-02-06 Changes in paid media Investments AO Q1
# Folder 1411 Digital Sales\Z_Other\2025-02-06 Footprint Tips  Actions
# Folder 1412 Digital Sales\Insurance\2025-02-06 Changes in paid media insurances Q1
# Folder 1413 Digital Sales\Consumer Loans\2025-02-06 Changes in paid media loans Q1
# Folder 1414 Customer IT Systems & Processes\Process change\2025-02-07 Plan ahead adjustments from private banking
# Folder 1415 Hypotheken\Adviesteam Wonen\2025-02-07 Pilot Verhogen telefonisch ATW
# Folder 1416 Collections\Communication\2025-02-07 Sustainable Cure for Customers with arrears
# Folder 1417 Private Banking _ Wealth\Salespitches\2025-02-10 CFMM PriBa Slides
# Folder 1418 Verzekeren\ING Woonverzekering\2025-02-10 Home campaign spring 2025
# Folder 1419 Credit Cards\Commercial Credit Cards\2025-02-10 Digital Handling  BC programme request STP in TS2 Feature 8116387
# Folder 1420 Hypotheken\Adviesteam Wonen\2025-02-10 Adviesovereenkomst ATW Engels
# Folder 1421 Sparen\Z_Other\2025-02-10 Remove Ringfencing (ECO11) for Savings
# Folder 1422 Digital Sales\Investments - Verdi\2025-02-11 Links at top op ZOB product detail page
# Folder 1423 Betalen-Roodstand\ING Rood Staan\2025-02-11 Reduce unused ING Overdraft
# Folder 1424 Fraud\Process change\2025-01-28 Business App Limits
# Folder 1425 Private Banking _ Wealth\Ki\2025-02-11 Ki  information page in closed environment
# Folder 1426 Digital Sales\Investments - Verdi\2025-02-11 Add interest history to EB product detail page
# Folder 1427 Lenen zakelijk\Z_Other\2025-02-11 OT closed using customer data
# Folder 1428 Digital Sales\Investments - Verdi\2025-02-11 Small redesign of category page beleggen bij ING
# Folder 1429 Digital Sales\Investments - Verdi\2025-02-11 Redesign of category page beleggen bij ING
# Folder 1430 Lenen zakelijk\Consumenten Financieringen\2025-02-11 Consumenten Financiering
# Folder 1431 Persoonlijke Lening\Persoonlijke Lening\2025-02-12 Energy Saving Renovation Loan
# Folder 1432 Client Services\Other\2025-02-13 Call interaction English conversations Manilla
# Folder 1468 Current accounts\Zakelijke rekening\2025-02-26 Overrule MagDat for Open Business Current Account
# Folder 1469 Z_Other\Tribe Daily Banking & Digital First\2025-02-26 Risk based address verification in MO
# Folder 1470 Collections\Communication\2025-02-27 Communication Financial Fit Loan Remittance
# Folder 1471 Customer Data\Process change\2025-02-27 Setup Party Offboarding Orchestrator EPIC8453161
# Folder 1472 Digital Sales\Facebook Pixel & Google ads\2025-02-27 Meta tracking
# Folder 1473 Private Banking _ Wealth\Z_Other\2025-02-28 FactSet rapportage Duurzaamheid  Uitsluitingen
# Folder 1474 Beleggingsrekeningen\Vermogensadvies\2025-03-03 Private Markets treshold  model allocations
# Folder 1475 Z_Other\Tribe Daily Banking & Digital First\2025-03-03 Cashual 2025  sounding board
# Folder 1476 Verzekeren\Maverick\2025-03-03 MGA risk carrier contract
# Folder 1477 Hypotheken\Adviesteam Wonen\2025-03-03 Flyer project ontwikkelaar
# Folder 1478 Private Banking _ Wealth\Campagnes\2025-03-04 Private Markets campaign 2025  PM guide
# Folder 1479 Hypotheken\Z_Other\2025-03-04 Wijziging offerte op SMV
# Folder 1480 Digital Sales\Investments - Verdi\2025-03-04 CRO optimizations Q1
# Folder 1481 Digital Sales\Investments - Verdi\2025-03-04 CRO Investments Q1 2025
# Folder 1482 Payments_Giraal betvk\Z_Other\2025-03-05 8183060 (CASH) COMPLAINTS ON MOBILE
# Folder 1483 Beleggingsdiensten\Z_Other\2025-03-05 Support of W9forms by Investments for our USW Process
# Folder 1484 Persoonlijke Lening\Persoonlijke Lening\2025-03-05 Reusing Checked Evidence in Recurring Applications
# Folder 1485 Current accounts\Jongerenrekening\2022-02-15 Deactivate ISP Iris opening ChildYouth and help customer via MING
# Folder 1486 Sparen\Z_Other\2025-03-05 DGS wijzigingen april 2025
# Folder 1487 Hypotheken - WUB\Z_Other\2025-03-05 Sustainability - Online Home Scan
# Folder 1488 Hypotheken\Origination\2025-03-05 Improve rejection and cancellation process  FEATURE 3814343
# Folder 1489 Real Estate\Process change\2025-03-05 Valuation process (quality review and TPAR)
# Folder 1490 Z_Other\Tribe Business Lending\2025-03-06 Informing ING RM about BIP financing request by IMZ
# Folder 1491 KYC\Organisational change\2025-03-06 Data Analysts FCFP to Manilla Hubs
# Folder 1492 Customer Data\Process change\2025-03-06 5440848 Target for manage legal entity
# Folder 1493 Digital Sales\Investments - Verdi\2025-03-06 Ghost account investments with disclaimer
# Folder 1494 Private Banking _ Wealth\Campagnes\2025-03-07 Private Markets campaign 2025  scripts for promo and explainer videos
# Folder 1495 Private Banking _ Wealth\Z_Other\2025-03-07 Private Markets Campaign 2025  LinkedIn posts
# Folder 1496 Beleggingsrekeningen\Zelf op de Beurs\2025-03-07 Best Execution Policy 2025
# Folder 1497 Private Banking _ Wealth\Internetpagina\2025-03-07 Private Markets campaign 2025  website
# Folder 1498 Beleggingsrekeningen\Z_Other\2025-03-10 US Withholding Client reachout Wform
# Folder 1499 Payments_Giraal betvk\IDEAL (issuing en acquiring)\2025-03-10 Revoke certificate iDeal (acquiring)
# Folder 1500 Payments_Giraal betvk\IDEAL (issuing en acquiring)\2025-03-10 CAR Function Ideal (acquiring)
# Folder 1501 Hypotheken\Z_Other\2025-03-10 Auto adjust LTV
# Folder 1502 Sparen\Pensioenspaarrekening\2022-02-16 Stop renewing Pension Saving accounts
# Folder 1503 Hypotheken\Adviesteam Wonen\2025-03-11 OHD flyer
# Folder 1504 Facility Management\Other\2025-03-11 Replace VMS COS
# Folder 1505 Real Estate\Process change\2025-03-11 Extention CFP contract
# Folder 1506 Commercial Finance\Other\2025-03-12 FastTrack Flow in Lendscape
# Folder 1507 Hypotheken\Origination\2025-03-12 Aanvraag Offerte en Tekendatumrente
# Folder 1508 Beleggingsrekeningen\Z_Other\2025-03-13 Vrijvallen spaardepositos
# Folder 1509 Beleggingsrekeningen\Eenvoudig Beleggen\2025-03-13 Onboarding fallout retarget survey
# Folder 1510 Beleggingsrekeningen\Z_Other\2025-03-13 VIA correctiebrief over 2024
# Folder 1511 Verzekeren\ING Rechtsbijstandverzekering voor Particulieren\2025-03-13 Legal Aid Insurance  Change of conditions
# Folder 1512 Digital Sales\Z_Other\2025-03-13 Aanpassingen Content Kijk Vooruit 2025
# Folder 1513 Z_Other\Tribe Mortgages\2025-03-13 Upgrade Check  PDF download
# Folder 1514 Z_Other\Tribe Mortgages\2025-03-13 Upgrade Check  Consent for sharing data
# Folder 1515 Verzekeren\Maverick\2025-03-13 Car salesflow Allianz
# Folder 1516 Current accounts\Betaalrekening\2025-03-14 Dutch Review article March 2025 insight conv
# Folder 1517 Beleggingsrekeningen\Vermogensbeheer\2025-03-14 Market turmoil communication
# Folder 1518 Branding\Communication\2025-03-14 2025 Lieke Martens
# Folder 1519 Digital Channels\Other\2025-03-17 Configure links in Progressive Disclosure
# Folder 1520 Beleggingsdiensten\Z_Other\2025-03-17 Overzicht Opgaaf Werkelijk Rendement (OWR) beleggingen per jaar
# Folder 1521 Digital Sales\Investments - Verdi\2025-03-17 Ghost account Self Invest
# Folder 1522 Digital Sales\Consumer Loans\2025-03-17 Simple Loans Widget
# Folder 1523 Current accounts\En_of betaalrekening\2025-03-17 Comply with PiFi legislation  Implement Maybe journey for DAAH
# Folder 1524 Digital Sales\Investments - Verdi\2025-03-18 Activation Selfinvest 30
# Folder 1525 Beleggingsrekeningen\Z_Other\2025-03-18 Aanpassing Debetrente Beleggingsrekening
# Folder 1526 Digital Sales\Investments - Verdi\2025-03-18 Digital activation cashback easy and self invest Q2 2025
# Folder 1527 Easy Banking\Communication\2025-03-18 Processing transaction data of legal entities in TRACR for marketing purposes
# Folder 1528 Beleggingsrekeningen\Z_Other\2025-03-18 Onboarding PIFI proof
# Folder 1529 Private Banking _ Wealth\Customer Journeys\2025-03-19 Pilot Service Models Financial Planning Private Banking
# Folder 1530 Customer Data\Other\2025-03-19 Feature 8199145  8199161  MIA record retention on DBaaS   data cleaning  solution
# Folder 1531 Customer Data\Other\2025-01-23 UBO registry call
# Folder 1532 Client Services\COO Business Banking Daily Banking Operations\2025-03-20 Business Cards
# Folder 1533 Beleggingsrekeningen\Z_Other\2025-03-20 Onboarding PIFI Proof
# Folder 1534 Beleggingsrekeningen\Eenvoudig Beleggen\2025-03-20 EB  Strategy Allocation and Strategy positions  new entry points
# Folder 1535 Private Banking _ Wealth\Internetpagina\2025-03-21 Private Markets campaign 2025  Halito webpage
# Folder 1536 Beleggingsrekeningen\Eenvoudig Beleggen\2025-03-24 Order Uitvoering pagina
# Folder 1537 Customer Intelligence\Financial Health\2025-03-24 AllowMore Inapp Checktool
# Folder 1538 Beleggingsdiensten\ING Investment Office\2025-03-24 SFDR 2.17 definition modification
# Folder 1539 Customer Data\Process change\2025-03-24 Magdat  adding of new EVA checks
# Folder 1540 Beleggingsrekeningen\Vermogensbeheer\2025-03-24 DPM Cashback Q2 2025
# Folder 1541 Hypotheken - WUB\Unsecured mailen\2025-03-26 TEST
# Folder 1542 Hypotheken - WUB\Unsecured mailen\2025-03-26 New webform Renting as an Investment
# Folder 1543 Hypotheken - WUB\Unsecured mailen\2025-03-26 Renting as an Investment  Webform
# Folder 1544 Payments_Giraal betvk\Z_Other\2025-03-26 Instant Payments Regulation
# Folder 1545 Payments Cards Issuing\Betaalpas particulier (cards issuing)\2025-03-26 Enhance replace debit card flow
# Folder 1546 Payments Cards Issuing\Z_Other\2025-03-26 debit card details findable in MING(Z) via F12 (dev tools)
# Folder 1547 Payments Cards Issuing\Betaalpas particulier (cards issuing)\2025-03-26 Debit card details visible in MING(Z) F12
# Folder 1548 Payments_Giraal betvk\SEPA CT (MING en app, enkel_mv en ink)\2025-03-26 Direct initiation payment API
# Folder 1549 HR Processes & Systems\Communication\2025-03-27 test
# Folder 1550 Beleggingsrekeningen\Eenvoudig Beleggen\2025-03-27 Terms  conditions Cashback Q22025
# Folder 1551 Real Estate\Process change\2025-03-27 Target new REF loan applications Process in PEGA  Phase 1 (Epic 7813580)
# Folder 1552 Digital Sales\Insurance\2025-03-27 Postcode field on pages (Home Insurance widget)
# Folder 1553 Current accounts\Z_Other\2025-03-27 Change Automate holds in seizure process
# Folder 1554 Z_Other\Tribe Daily Banking & Digital First\2025-03-27 Automate placing holds via SMApi in seizure process
# Folder 1555 Current accounts\Z_Other\2025-03-27 Automate placing holds via SeizureManagementAPI
# Folder 1556 Sparen\Z_Other\2025-03-27 Rentewijziging H1 2025
# Folder 1557 Hypotheken\Z_Other\2025-03-28 Mortgage Check Improve Event Pension
# Folder 1558 Hypotheken - WUB\Unsecured mailen\2025-03-28 Emailadressen uit communicatie Stater verwijderen
# Folder 1559 Payments Reporting\New Product\2025-03-28 Realtime account reporting API
# Folder 1560 Hypotheken\Execution Only Service\2025-03-28 Convert mortgage without advice  going live
# Folder 1561 Beleggingsrekeningen\Zelf op de Beurs\2025-03-28 Cashback campaign Q2 (inc Katsjing EB and ZOB)
# Folder 1562 Credit Cards\Creditcard\2025-03-28 Katsjing Campaign April 2025
# Folder 1563 KYC\Process change\2025-03-31 Embed Systran to Translation Requests in PEGA
# Folder 1564 Private Banking _ Wealth\Customer Journeys\2025-03-31 PriBa contact strategy
# Folder 1565 Sparen\Groei Groter Rekening\2025-03-31 Winactie GGR en OSR Kind 2025
# Folder 1566 Customer IT Systems & Processes\Process change\2025-03-31 TTM expansion to customers
# Folder 1567 Private Banking _ Wealth\Salespitches\2025-03-31 Salespitch MSP
# Folder 1568 Sparen\New Product\2025-03-31 Kwartaal Spaarrekening for PI
# Folder 1569 Digital Sales\Z_Other\2025-04-01 Linkbuilding
# Folder 1570 Beyond Banking\Financial Health\2025-04-01 Measuring effectiveness of financial health propositions
# Folder 1571 Hypotheken\Morse\2025-04-01 HDN Bridge for Morse PPMEPIC0051107
# Folder 1572 Verzekeren\Z_Other\2025-04-01 Katsjing Campaign (Kings version)
# Folder 1573 Digital Sales\Investments - Verdi\2025-04-01 Investment Pegasus pages
# Folder 1574 Digital Sales\Investments - Verdi\2025-04-01 EAA investments
# Folder 1575 Current accounts\Z_Other\2025-04-01 Automate plaing holds in the seizure process
# Folder 1576 Current accounts\Z_Other\2025-04-01 Placing automatic holds in seizure process
# Folder 1577 Current accounts\Z_Other\2025-04-01 Automation of holds in seizure process
# Folder 1578 Z_Other\Tribe Mortgages\2025-04-01 Term Life  insuranceinformation letterinsurance ends
# Folder 1579 Beleggingsrekeningen\Vermogensbeheer\2025-04-02 Quarterly report layout improvements
# Folder 1580 Hypotheken\Adviesteam Wonen\2025-04-02 Externe presentatieblokken event
# Folder 1581 Private Banking _ Wealth\Internetpagina\2025-04-02 Private Markets campaign 2025  bestaande klanten  Halito webpage
# Folder 1582 Persoonlijke Lening\Persoonlijke Lening\2025-04-02 EV Tool 2.0 Total costs comparison gas versus EV
# Folder 1583 Beleggingsrekeningen\Zelf op de Beurs\2025-04-02 Commerciele uitingen ZOB squad Q2 2025
# Folder 1584 Z_Other\Tribe Daily Banking & Digital First\2025-04-02 ING Points access for minors (1218 years)
# Folder 1585 Persoonlijke Lening\Persoonlijke Lening\2025-04-02 Campaign car loan and EV
# Folder 1586 Lenen zakelijk\Z_Other\2025-04-02 Unauthorized use of obligofacilities  client letter
# Folder 1587 Digital Sales\Google Ads\2025-04-02 Google ads policy violation adjust privacy statement and banner
# Folder 1588 Z_Other\Tribe Investments\2025-04-03 Beleggen Mail Q2 2025
# Folder 1589 Beleggingsrekeningen\Z_Other\2025-04-03 Exemption flow for Ringfenced clients
# Folder 1590 Z_Other\Tribe Daily Banking & Digital First\2025-04-03 20250403 Campaign Katsjing 2025
# Folder 1591 Beleggingsdiensten\Eenvoudig Beleggen\2025-04-03 Add FAQ about the cashback campaign to meest gestelde vragen page
# Folder 1592 Lenen zakelijk\Z_Other\2025-04-04 Fast Track Decisioning 2.0
# Folder 1593 Fraud\Process change\2025-04-04 ABC constructions review to KYC
# Folder 1594 Hypotheken\Adviesteam Wonen\2025-04-04 Dienstverlening op Maat (DVOM) 2.0
# Folder 1595 Beyond Banking\Financial Health\2025-04-07 Statistical analysis to improve Financial Health of ING customers
# Folder 1596 Beleggingsrekeningen\Eenvoudig Beleggen\2025-04-07 Add FAQ CT cashback
# Folder 1597 Client Services\COO Business Banking Daily Banking Operations\2025-04-07 PreCDD UBO Outreach
# Folder 1598 Digital Sales\Facebook Pixel & Google ads\2025-04-07 Enhanced Conversions MetaGoogle Hashed Email
# Folder 1599 Datamanagement\Other\2025-04-07 2025 Move IT asset from BE to NL (REF)
# Folder 1600 Current accounts\Betaalrekening\2025-04-07 PPMEPIC0040069
# Folder 1601 Digital Sales\Mortgages\2025-04-07 Mortgage Raise flow
# Folder 1602 Beleggingsrekeningen\Vermogensbeheer\2025-04-07 Beleggingsaanpak in onzekere tijden emails (DPM en EB)
# Folder 1603 Z_Other\Tribe Business Lending\2025-04-07 MTL Internal ING accounts
# Folder 1604 Beleggingsrekeningen\Eenvoudig Beleggen\2025-04-08 Changes to EB pages on ing.nl (Q22025)
# Folder 1605 Beleggingsrekeningen\Z_Other\2025-04-08 Excuusbrief TOB
# Folder 1606 Verzekeren\New Product\2025-04-08 Embedded group insurance products for subscription packages  CC for PI BB  PriBa
# Folder 1607 Z_Other\Tribe Daily Banking & Digital First\2025-04-08 SMJ  Gen Z Selfemployed
# Folder 1608 Persoonlijke Lening\Persoonlijke Lening\2025-04-08 Improving the Ockto Customer Journey
# Folder 1609 Kantoren\ING Servicepunten\2025-04-08 Appointment booking ISP 182387 263883 182460
# Folder 1610 Fraud\Process change\2025-04-09 Verify Mobile nr  Add verification step in Change mobile number journey (7906833)
# Folder 1611 Verzekeren\Maverick\2025-04-09 Maverick RfP TPA Claims
# Folder 1612 Lease\Process change\2025-04-09 Implement MagDat Service
# Folder 1613 Beleggingsrekeningen\Eenvoudig Beleggen\2025-04-09 EB fund name change  closed environment
# Folder 1614 Z_Other\Tribe Payments\2024-10-08 Migration Second Line fiat process DBNL to PSS
# Folder 1615 Payments_Giraal betvk\Buitenland BTL MING(-Z)\2025-04-10 Communicate new proposition TIP
# Folder 1616 Pakketten\New Product\2025-04-10 Subscription Strategy PI
# Folder 1617 Current accounts\Betaalrekening\2025-04-10 Deposit salary 50 euro cashback legal expenses insurance
# Folder 1618 Sparen\Zakelijke Kwartaal Spaarrekening\2025-04-10 Special index for Zakelijke Kwartaal Spaarrekening
# Folder 1619 Sparen\Oranje Spaarrekening\2025-04-10 Inapp campaign to stimulate automatic saving
# Folder 1620 Easy Banking\Communication\2025-04-11 Katsjing campagn
# Folder 1621 Beleggingsrekeningen\Vermogensbeheer\2025-04-11 cDPM Overview building blocks
# Folder 1622 Credit Cards\Creditcard\2025-04-11 Automation of restitution yearly fee
# Folder 1623 NFR & Compliance Processes & Systems\Other\2025-04-11 Implementatie Ondertekeningsbeleid
# Folder 1624 Verzekeren\New Product\2025-04-14 Subscription Packages  embedded group insurance products for PI BB CC  PriBa
# Folder 1625 Beleggingsrekeningen\Vermogensbeheer\2025-04-14 SFDR periodic reports 2024
# Folder 1626 Verzekeren\Maverick\2025-04-14 Process car insurance request from the distributor
# Folder 1627 Hypotheken\Z_Other\2025-04-14 Upgrader  Financing option information at WUJW
# Folder 1628 Digital Sales\Google Ads\2025-04-14 Google ads policy violation adjust banner and privacy statement
# Folder 1629 Hypotheken\ILM\2025-04-15 Lowering market value and redemtion of construction deposit
# Folder 1630 Credit Cards\Creditcard\2025-04-15 Overhaul of authentication level Card processes
# Folder 1631 Lenen zakelijk\Z_Other\2025-02-24 MC to ML  EPICPPM 5415200
# Folder 1632 Payments_Giraal betvk\SEPA Direct Debit (credit en debit)\2025-04-15 SDD 18 (temp solution)
# Folder 1633 Beleggingsrekeningen\Eenvoudig Beleggen\2025-04-16 Easy  Pension  prognosis tile
# Folder 1634 Verzekeren\New Product\2025-04-16 ING Income Protection Insurance distribution (AOV)
# Folder 1635 KYC\Process change\2025-04-16 STP 2.0
# Folder 1636 Private Banking _ Wealth\Z_Other\2025-04-16 Celebration Private Markets 1 Miljard
# Folder 1637 Current accounts\Jongerenrekening\2022-02-23 Adjust SBETKJ06 message after opening childyouth account via MINGApp
# Folder 1638 Digital Sales\Payments and Cards\2022-02-25 CC Think Vakantie Experience
# Folder 1639 Private Banking _ Wealth\Salespitches\2022-02-25 Charity slides in salespitch
# Folder 1640 C:\Users\TE61EI\ING\Product Evaluation and Risk Assessment Library (PEARL) - Documents\Pearl_Repository\Payments Cards Issuing\Betaalpas particulier (cards issuing)\2022-03-15 EMVOV Part 2 IBANPANkoppeling
# Folder 1641 Current accounts\En_of betaalrekening\2022-03-15 Digitalization Add accountholder to current account
# Folder 1642 Z_Other\Tribe Daily Banking & Digital First\2022-03-22 Mobile Onboarding R1 Ukrainian Refugees
# Folder 1643 Beleggingsrekeningen\Vermogensbeheer\2022-03-22 Communication clients regarding old DPM portfolios
# Folder 1644 Beleggingsrekeningen\Z_Other\2022-03-24 Beleggersbarometer
# Folder 1645 Lenen zakelijk\Z_Other\2022-03-24 Interest averaging extention validity
# Folder 1646 Digital Sales\Mortgages\2022-03-28 Optimization product homepage (level 1) Mortgages
# Folder 1647 Digital Sales\Current accounts\2022-03-29 Child Current Account  Balance Amount Selection
# Folder 1648 Payments_Giraal betvk\iDEAL 2.0\2022-04-06 Ideal 2.0 Release 2
# Folder 1649 Commercial Finance\Other\2022-04-01 Dukebox
# Folder 1650 Current accounts\Betaalrekening\2022-01-31 Introduction GBB
# Folder 1651 Beleggingsrekeningen\Z_Other\2022-04-02 MiFID II Sustainability
# Folder 1652 Z_Other\Tribe Digital & Customer Interactions\2022-04-07 Multi Profiles
# Folder 1653 KYC\Process change\2022-04-08 Daily batch driven events (FEC related)
# Folder 1654 Payments_Giraal betvk\Z_Other\2022-04-11 EPIC0092399 DiBo preperation next steps
# Folder 1655 Document & Content Services\Process change\2022-04-13 Inspire migration
# Folder 1656 Current accounts\Betaalrekening\2022-04-14 Communication Oranje Pakket Extra
# Folder 1657 Facility Management\Other\2022-04-15 TBS
# Folder 1658 Current accounts\Betaalrekening\2022-04-19 Pakketwissel OPK naar OP vanwege Inzicht
# Folder 1659 Private Banking _ Wealth\Z_Other\2022-04-25 Financing direct major shareholder via own legal entity
# Folder 1660 KYC\Process change\2022-04-26 ING Hub KYC onboarding event triggers and CDD  LR NR  mass sme mid corp and priba
# Folder 1661 Z_Other\Tribe Payments\2022-05-01 CASY NL AIS PSD2
# Folder 1662 Procurement\Other\2022-05-11 Vendor Accounts spend reconciliation
# Folder 1663 Digital Sales\Campaign Management\2022-05-13 Optin to optout email strategy
# Folder 1664 Z_Other\Tribe Daily Banking & Digital First\2022-05-16 Negative Interest Rates (NIR) on Client Level
# Folder 1665 C:\Users\TH74IH\ING\Product Evaluation and Risk Assessment Library (PEARL) - Documents\Pearl_Repository\Payments Cards Issuing\Betaalpas particulier (cards issuing)\2022-05-18 VDDMC Pilot
# Folder 1666 HR Processes & Systems\Other\2022-05-19 Survey PWCTrue Voice for CLA negotiaton
# Folder 1667 HR Processes & Systems\Communication\2022-05-19 Survey Tool PWCTrue Voice
# Folder 1668 HR Processes & Systems\Other\2022-05-19 Health Check for ING NL employees with Tigra
# Folder 1669 Beleggingsrekeningen\Eenvoudig Beleggen\2022-06-02 Easy Invest customer engagement
# Folder 1670 Current accounts\Betaalrekening\2022-06-10 Minors with a CA or SA
# Folder 1671 Beleggingsrekeningen\Eenvoudig Beleggen\2022-06-13 Awareness and consideration experiment
# Folder 1672 Digital Sales\Current accounts\2022-06-13 Refreshing excisting content
# Folder 1673 Z_Other\Tribe Daily Banking & Digital First\2022-06-15 ID Verification (uitbesteed via WBCLT)
# Folder 1674 Sparen\Groei Groter Rekening\2022-06-21 Terminate GGR if new legal representative is not registered to the account
# Folder 1675 Beleggingsrekeningen\Z_Other\2022-06-27 New Yield Graphs Investments in Mobile Banking App
# Folder 1676 Current accounts\Studentenrekening\2022-06-29 Studentenpiek flyer Assisted channels
# Folder 1677 Customer IT Systems & Processes\Other\2022-06-30 Call reason analysis (with SAM  Twilio)
# Folder 1678 Betalen-Roodstand\ING Rood Staan voor studenten\2022-07-04 Terms and conditions change (tap closed Lapwing)
# Folder 1679 Z_Other\Tribe Business Lending\2022-06-30 FT Online Intake
# Folder 1680 Z_Other\Tribe Digital & Customer Interactions\2022-07-08 remove SSO dialogue
# Folder 1681 Z_Other\Tribe Digital & Customer Interactions\2022-07-08 reassessment biometrics
# Folder 1682 Sparen\Groen Spaardeposito\2022-07-13 Opening Groen Spaardeposito
# Folder 1683 Current accounts\Z_Other\2022-07-14 EPIC0099181  Implement eVORI
# Folder 1684 Lenen zakelijk\Z_Other\2022-07-20 Implementation Cocoa frontend in Blend Apply Credit
# Folder 1685 Sparen\Vreemde valuta deposito\2022-07-21 Salesstop Foreign Term Deposit followed by discontinuation of the product
# Folder 1686 Customer Intelligence\Insights\2022-07-27 Financial Health questionaire
# Folder 1687 Pakketten\Oranjepakket met korting\2022-07-29 Remove paper services from Oranje Pakket met Korting STRY3525942
# Folder 1688 Commercial Finance\Other\2022-08-08 Supplyfy import finance
# Folder 1689 Fraud\Process change\2022-08-12 Line Busy API
# Folder 1690 Persoonlijke Lening\Persoonlijke Lening\2022-08-16 Pilot Beyond
# Folder 1691 Customer IT Systems & Processes\Communication\2022-08-17 Income  Expense graph
# Folder 1692 Lenen zakelijk\Z_Other\2022-08-18 Business Intermediary Portal Feature MultiFactor Authentication
# Folder 1693 Persoonlijke Lening\Persoonlijke Lening\2022-08-19 MLA is sufficient NDI is not sufficient
# Folder 1694 Z_Other\Tribe Daily Banking & Digital First\2022-08-22 Check need for identification
# Folder 1695 Beleggingsrekeningen\Z_Other\2022-08-23 Change QI status DB  NL (EPIC0100249)
# Folder 1696 Z_Other\Tribe Investments\2022-08-24 (pre) contractual SFRD obligations
# Folder 1697 Z_Other\Tribe Daily Banking & Digital First\2022-08-24 MT16 (Minors Turning 16)
# Folder 1698 Payments Acquiring\Accepteren betaalpas (cards acquiring)\2022-08-29 Merchant Approved Transactions (MAT)
# Folder 1699 Customer IT Systems & Processes\Process change\2022-08-31 Automisation of Authorisation and Identification through call
# Folder 1700 Digital Sales\Consumer Loans\2022-09-06 Enticement think active algemeen 1325
# Folder 1701 Digital Sales\Consumer Loans\2022-09-12 ACOV 6440 verbouwen
# Folder 1702 HR Processes & Systems\Other\2022-09-12  Improving Wft and MiFID E2E reporting process
# Folder 1703 Beleggingsrekeningen\Zelf op de Beurs\2022-09-12 NN Dutch Fund Merger
# Folder 1704 Payments Reporting\Electronisch verantwoording (p+z)\2025-02-17 Initial Review product
# Folder 1705 Kantoren\ING Ondernemerslobby\2025-04-09 Initial Review product
# Folder 1706 Credit Cards\Creditcard\2025-02-11 Intermediate Review product
# Folder 1707 Payments_Giraal betvk\ING Checkout\2025-03-11 Initial Review product
# Folder 1708 Lenen zakelijk\Consumenten Financieringen\2025-02-25 Intermediate Review product
# Folder 1709 Hypotheken\Review multiple products\2025-04-03 Intermediate Review multiple products
# Folder 1710 Hypotheken\Beleggershypotheek\2025-04-01 Intermediate Review product
# Folder 1711 Hypotheken\Review multiple products\2025-04-03 Intermediate Review multiple products
# Folder 1712 Hypotheken\Fondsenmix hypotheek\2025-04-01 Intermediate Review product
# Folder 1713 Hypotheken\MeerWaarde hypotheek\2025-04-01 Intermediate Review product
# Folder 1714 Hypotheken - WUB\WUB Hypotheek met Beleggingsrekening\2024-04-15 Intermediate Review product
# Folder 1715 Hypotheken - WUB\WUB SpaarXtra Hypotheek\2025-04-14 Complete Review product
# Folder 1716 Lenen zakelijk\Review multiple products\2025-03-24 Complete Review multiple products4
# Folder 1717 Lenen zakelijk\Review multiple products\2025-03-24 Complete Review multiple products4
# Folder 1718 Lenen zakelijk\Review multiple products\2025-03-24 Complete Review multiple products4
# Folder 1719 Lenen zakelijk\Review multiple products\2025-03-24 Complete Review multiple products4
# Folder 1720 Hypotheken\Bankspaarhypotheek variant 1\2025-04-01 Intermediate Review product
# Folder 1721 Hypotheken\Bankspaarhypotheek variant 2\2025-04-01 Intermediate Review product
# Folder 1722 Hypotheken\ING Spaarhypotheek\2025-04-01 Intermediate Review product
# Folder 1723 Current accounts\Review multiple products\2025-03-26 Complete Review multiple products
# Folder 1724 Current accounts\Review multiple products\2025-03-26 Complete Review multiple products
# Folder 1725 Hypotheken\Maatwerkhypotheek\2025-04-03 Intermediate Review product
# Folder 1726 Hypotheken\Spaarhypotheek\2025-04-01 Intermediate Review product
# Folder 1727 Hypotheken\UAP Spaarpolis\2025-04-01 Intermediate Review product
# Folder 1728 Hypotheken - WUB\WUB Balanced Life Hypotheek\2024-08-19 Intermediate Review product
# Folder 1764 Hypotheken\Lineaire hypotheek\2025-01-07 Intermediate Review product
# Folder 1765 Hypotheken\Overbruggingshypotheek\2025-01-21 Intermediate Review product
# Folder 1766 Hypotheken - WUB\WUB Annuiteiten Hypotheek\2025-02-12 Review product
# Folder 1767 Hypotheken - WUB\WUB Konstant Hypotheek\2025-01-02 Intermediate Review product
# Folder 1768 Hypotheken - WUB\WUB Lineaire Hypotheek\2025-02-12 Intermediate Review product
# Folder 1769 Hypotheken - WUB\WUB Overbruggingskrediet\2025-01-21 Intermediate Review product
# Folder 1770 Pakketten\Review multiple products\2024-11-28 Complete Review multiple products
# Folder 1771 Pakketten\Review multiple products\2024-11-28 Complete Review multiple products
# Folder 1772 Current accounts\Review multiple products\2024-11-14 Complete Review multiple products
# Folder 1773 Current accounts\Review multiple products\2024-11-14 Complete Review multiple products
# Folder 1774 Persoonlijke Lening Collections\Financieel Fit Krediet\2024-11-20 Initial Review product
# Folder 1775 Persoonlijke Lening\Herstructurering\2023-11-22 Initial Review product
# Folder 1776 Pakketten\Review multiple products\2024-11-28 Complete Review multiple products
# Folder 1777 Pakketten\Review multiple products\2024-11-28 Complete Review multiple products
# Folder 1778 Pakketten\Review multiple products\2024-11-28 Complete Review multiple products
# Folder 1779 Doorlopend Krediet\Studentenkrediet\2025-02-19 Complete Review product
# Folder 1780 Payments Acquiring\Koppeling Boekhoudpakket\2024-05-13 Initial Review product
# Folder 1781 Kantoren\ING Huizen\2024-09-03 Initial Review product
# Folder 1782 Lenen zakelijk\Review multiple products\2024-06-03 Initial Review multiple products
# Folder 1783 Lenen zakelijk\Review multiple products\2024-06-03 Initial Review multiple products
# Folder 1784 Lenen zakelijk\Review multiple products\2024-06-03 Initial Review multiple products
# Folder 1785 Lenen zakelijk\Review multiple products\2024-06-03 Initial Review multiple products
# Folder 1786 Lenen zakelijk\Review multiple products\2024-06-03 Initial Review multiple products
# Folder 1787 Portfolio Leases\Review multiple products\2024-10-10 Initial Review multiple products
# Folder 1788 Portfolio Leases\Review multiple products\2024-10-10 Initial Review multiple products
# Folder 1789 Portfolio Leases\Review multiple products\2024-10-10 Initial Review multiple products
# Folder 1790 Payments Reporting\Vergoedingenstaat (Statement of Fees)\2024-10-08 Initial Review product
# Folder 1791 Sparen\Sneltrein\2024-11-12 Initial Review product Sneltreinspaarrekening Dec 2024
# Folder 1792 Sparen\Spaarloonrekening\2024-09-26 Complete Review product
# Folder 1793 Lenen zakelijk\Review multiple products\2024-09-17 Initial Review multiple products
# Folder 1794 Lenen zakelijk\Review multiple products\2024-09-17 Initial Review multiple products
# Folder 1795 Credit Cards\Commercial Credit Cards\2024-11-21 Initial Review product
# Folder 1796 Doorlopend Krediet\Review multiple products\2024-10-28 Intermediate Review multiple products
# Folder 1797 Doorlopend Krediet\Review multiple products\2024-10-28 Intermediate Review multiple products
# Folder 1798 Payments Reporting\Afschriften (papier)\2024-10-08 Initial Review product
# Folder 1799 Vendor Leases\Review multiple products\2024-12-05 Initial Review multiple products
# Folder 1800 Vendor Leases\Review multiple products\2024-12-05 Initial Review multiple products
